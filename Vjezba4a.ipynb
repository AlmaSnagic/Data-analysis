# %%
import pandas as pd

# %%
df = pd.read_csv("employees.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df.head(10)
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5     Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6       Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7        NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8     Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9    Frances  Female    8/8/2002         6:51 AM  139852    7.524
#
#   Senior Management                  Team
# 0              True             Marketing
# 1              True                   NaN
# 2             False               Finance
# 3              True               Finance
# ...

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(322)

# %%
ukupno = df.shape[0] * df.shape[1]
broj_n = df.isnull().sum().sum()
iznos = broj_n/ukupno*100
iznos
# Out:
# np.float64(4.025)

# %%
df.isnull().sum()
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64

# %%
df.dropna()
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 2        Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004    1.389
# 5       Dennis    Male  4/18/1987         1:35 AM  115163   10.125
# ..         ...     ...        ...             ...     ...      ...
# 994     George    Male  6/21/2013         5:47 PM   98874    4.479
# 996    Phillip    Male  1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male  5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 2               False               Finance
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated(subset="First Name").sum()
# Out:
# np.int64(799)

# %%
df["First Name"].value_counts()
# Out:
# First Name
# Marilyn    11
# Jeremy     10
# Todd       10
# Barbara    10
# Irene       9
#            ..
# Tammy       1
# Eugene      1
# Brian       1
# Keith       1
# David       1
# Name: count, Length: 200, dtype: int64

# %%
df["Gender"].value_counts(normalize=True)*100
# Out:
# Gender
# Female    50.409357
# Male      49.590643
# Name: proportion, dtype: float64

# %%
len(df["First Name"].unique())
# Out:
# 201

# %%
df.replace({'Finance': 'Finansije'})
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df.replace({'Male': 'M', 'Female': 'F'})
# Out:
#     First Name Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas      M    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas      M   3/31/1996         6:53 AM   61933    4.170
# 2        Maria      F   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry      M    3/4/2005         1:00 PM  138705    9.340
# 4        Larry      M   1/24/1998         4:47 PM  101004    1.389
# ..         ...    ...         ...             ...     ...      ...
# 995      Henry    NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip      M   1/31/1984         6:30 AM   42392   19.675
# 997    Russell      M   5/20/2013        12:39 PM   96914    1.421
# 998      Larry      M   4/20/2013         4:45 PM   60500   11.985
# 999     Albert      M   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df['Gender'] = df['Gender'].replace(['Male','Female'], ['M', 'F'])
df.head()
# Out:
#   First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas      M   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas      M  3/31/1996         6:53 AM   61933    4.170
# 2      Maria      F  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry      M   3/4/2005         1:00 PM  138705    9.340
# 4      Larry      M  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df['Nova kolona'] = df['Salary'] + (df['Salary']*df['Bonus %'])/100
df
# Out:
#     First Name Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas      M    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas      M   3/31/1996         6:53 AM   61933    4.170
# 2        Maria      F   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry      M    3/4/2005         1:00 PM  138705    9.340
# 4        Larry      M   1/24/1998         4:47 PM  101004    1.389
# ..         ...    ...         ...             ...     ...      ...
# 995      Henry    NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip      M   1/31/1984         6:30 AM   42392   19.675
# 997    Russell      M   5/20/2013        12:39 PM   96914    1.421
# 998      Larry      M   4/20/2013         4:45 PM   60500   11.985
# 999     Albert      M   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team   Nova kolona
# 0                True             Marketing  104066.04060
# ...

# %%
i=df['Bonus %'].idxmax()
df.loc[i]
# Out:
# First Name                 Robert
# Gender                          M
# Start Date              3/11/2007
# Last Login Time          11:20 AM
# Salary                     135882
# Bonus %                    19.944
# Senior Management           False
# Team                        Legal
# Nova kolona          162982.30608
# Name: 488, dtype: object

# %%
i=df['Salary'].idxmin()
df.loc[i]
# Out:
# First Name               Michael
# Gender                         M
# Start Date             7/30/1993
# Last Login Time          5:35 PM
# Salary                     35013
# Bonus %                   14.879
# Senior Management          False
# Team                     Product
# Nova kolona          40222.58427
# Name: 576, dtype: object

# %%
def bonus(x):
    return df['Salary']*df['Bonus %']/100 - df['Salary']

df['Bonus dolari']= df.apply(bonus, axis=1)
df
# Out:
#   Cell In[46], line 4
#     df['Bonus dolari']= df.apply[bonus, axis=1]
#                                         ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
df.rename(columns={'First Name'})

# %%
df.describe()
# Out:
#               Salary      Bonus %    Nova kolona
# count    1000.000000  1000.000000    1000.000000
# mean    90662.181000    10.207555   99850.419948
# std     32923.693342     5.528481   36498.486968
# min     35013.000000     1.015000   36858.928080
# 25%     62613.000000     5.401750   68885.929400
# 50%     90428.000000     9.838500   99268.145865
# 75%    118740.250000    14.838000  130006.352785
# max    149908.000000    19.944000  178258.600960

# %%
df1 = pd.read_csv('chicago.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32063 entries, 0 to 32062
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    32062 non-null  object
#  1   Position Title          32062 non-null  object
#  2   Department              32062 non-null  object
#  3   Employee Annual Salary  32062 non-null  object
# dtypes: object(4)
# memory usage: 1002.1+ KB

# %%
df1.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
df1.nunique()
# Out:
# Name                      31776
# Position Title             1093
# Department                   35
# Employee Annual Salary     1156
# dtype: int64

# %%
df1['Name'].str.lower()
# Out:
# 0            aaron,  elvia j
# 1          aaron,  jeffery m
# 2             aaron,  karina
# 3        aaron,  kimberlei r
# 4        abad jr,  vicente m
#                 ...
# 32058     zygowicz,  peter j
# 32059      zymantas,  mark e
# 32060    zyrkowski,  carlo e
# 32061    zyskowski,  dariusz
# 32062                    NaN
# Name: Name, Length: 32063, dtype: object

# %%
df1.dropna(how='all', inplace=True)
df1.tail()
# Out:
#                       Name                  Position Title        Department  \
# 32057  ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32058   ZYGOWICZ,  PETER J                  POLICE OFFICER            POLICE
# 32059    ZYMANTAS,  MARK E                  POLICE OFFICER            POLICE
# 32060  ZYRKOWSKI,  CARLO E                  POLICE OFFICER            POLICE
# 32061  ZYSKOWSKI,  DARIUSZ         CHIEF DATA BASE ANALYST              DoIT
#
#       Employee Annual Salary
# 32057              $99528.00
# 32058              $87384.00
# 32059              $84450.00
# 32060              $87384.00
# 32061             $113664.00

# %%
df1['Department']=df1['Department'].str.replace('MGMNT', 'MANAGMENT')
df1
# Out:
#                       Name                  Position Title        Department  \
# 0          AARON,  ELVIA J                WATER RATE TAKER   WATER MANAGMENT
# 1        AARON,  JEFFERY M                  POLICE OFFICER            POLICE
# 2           AARON,  KARINA                  POLICE OFFICER            POLICE
# 3      AARON,  KIMBERLEI R        CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4      ABAD JR,  VICENTE M               CIVIL ENGINEER IV   WATER MANAGMENT
# ...                    ...                             ...               ...
# 32057  ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32058   ZYGOWICZ,  PETER J                  POLICE OFFICER            POLICE
# 32059    ZYMANTAS,  MARK E                  POLICE OFFICER            POLICE
# 32060  ZYRKOWSKI,  CARLO E                  POLICE OFFICER            POLICE
# 32061  ZYSKOWSKI,  DARIUSZ         CHIEF DATA BASE ANALYST              DoIT
#
#       Employee Annual Salary
# ...

# %%
df1['Employee Annual Salary']=df1['Employee Annual Salary'].str.replace('$', '').astype(float)
df1
# Out:
#                       Name                  Position Title        Department  \
# 0          AARON,  ELVIA J                WATER RATE TAKER   WATER MANAGMENT
# 1        AARON,  JEFFERY M                  POLICE OFFICER            POLICE
# 2           AARON,  KARINA                  POLICE OFFICER            POLICE
# 3      AARON,  KIMBERLEI R        CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4      ABAD JR,  VICENTE M               CIVIL ENGINEER IV   WATER MANAGMENT
# ...                    ...                             ...               ...
# 32057  ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32058   ZYGOWICZ,  PETER J                  POLICE OFFICER            POLICE
# 32059    ZYMANTAS,  MARK E                  POLICE OFFICER            POLICE
# 32060  ZYRKOWSKI,  CARLO E                  POLICE OFFICER            POLICE
# 32061  ZYSKOWSKI,  DARIUSZ         CHIEF DATA BASE ANALYST              DoIT
#
#        Employee Annual Salary
# ...

# %%
df1['Employee Annual Salary'].describe()
# Out:
# count     32062.000000
# mean      80204.178634
# std       25098.329868
# min           0.960000
# 25%       72862.400000
# 50%       84450.000000
# 75%       93240.000000
# max      300000.000000
# Name: Employee Annual Salary, dtype: float64

# %%
i=df1['Employee Annual Salary'].idxmin()
df1.loc[i]
# Out:
# Name                                 KOCH,  STEVEN
# Position Title            ADMINISTRATIVE SECRETARY
# Department                          MAYOR'S OFFICE
# Employee Annual Salary                        0.96
# Name: 15102, dtype: object

# %%
df1['Employee Annual Salary'].nlargest()
# Out:
# 8184     300000.0
# 7954     216210.0
# 25532    202728.0
# 8924     197736.0
# 8042     197724.0
# Name: Employee Annual Salary, dtype: float64

# %%
df1['Employee Annual Salary'].nsmallest()
# Out:
# 15102       0.96
# 12       2756.00
# 27       2756.00
# 47       2756.00
# 295      2756.00
# Name: Employee Annual Salary, dtype: float64

# %%
filter = df1['Position Title'].str.lower().str.contains('water')
df1[filter]
# Out:
#                        Name                                 Position Title  \
# 0           AARON,  ELVIA J                               WATER RATE TAKER
# 554      ALUISE,  VINCENT G             FOREMAN OF WATER PIPE CONSTRUCTION
# 671         ANDER,  PERRY A                               WATER CHEMIST II
# 685     ANDERSON,  ANDREW J  DISTRICT SUPERINTENDENT OF WATER DISTRIBUTION
# 702       ANDERSON,  DONALD             FOREMAN OF WATER PIPE CONSTRUCTION
# ...                     ...                                            ...
# 29669        VERMA,  ANUPAM           MANAGING ENGINEER - WATER MANAGEMENT
# 30239   WASHINGTON,  JOSEPH                              WATER CHEMIST III
# 30544       WEST,  THOMAS R                   GEN SUPT OF WATER MANAGEMENT
# 30991    WILLIAMS,  MATTHEW             FOREMAN OF WATER PIPE CONSTRUCTION
# 31405  WOODRIDGE,  ROBERT L             FOREMAN OF WATER PIPE CONSTRUCTION
#
#             Department  Employee Annual Salary
# ...
