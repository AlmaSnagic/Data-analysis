# %%
import pandas as pd

# %%
fortune = pd.read_csv('fortune1000.csv')

# %%
fortune.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rank       1000 non-null   int64
#  1   Company    1000 non-null   object
#  2   Sector     1000 non-null   object
#  3   Industry   1000 non-null   object
#  4   Location   1000 non-null   object
#  5   Revenue    1000 non-null   int64
#  6   Profits    1000 non-null   int64
#  7   Employees  1000 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 62.6+ KB

# %%
fortune.head()
# Out:
#    Rank             Company       Sector  \
# 0     1             Walmart    Retailing
# 1     2         Exxon Mobil       Energy
# 2     3               Apple   Technology
# 3     4  Berkshire Hathaway   Financials
# 4     5            McKesson  Health Care
#
#                                    Industry           Location  Revenue  \
# 0                     General Merchandisers    Bentonville, AR   482130
# 1                        Petroleum Refining         Irving, TX   246204
# 2               Computers, Office Equipment      Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 4                  Wholesalers: Health Care  San Francisco, CA   181241
#
#    Profits  Employees
# 0    14694    2300000
# 1    16150      75600
# 2    53394     110000
# 3    24083     331000
# 4     1476      70400

# %%
fortune.describe()
# Out:
#              Rank        Revenue       Profits     Employees
# count  1000.00000    1000.000000   1000.000000  1.000000e+03
# mean    500.49600   13535.525000    894.093000  3.302800e+04
# std     288.81727   28820.519135   3297.063594  9.042769e+04
# min       1.00000    1895.000000 -23119.000000  5.200000e+01
# 25%     250.75000    2898.250000     82.750000  6.405250e+03
# 50%     500.50000    5113.000000    282.500000  1.251950e+04
# 75%     750.25000   11386.000000    784.500000  2.812500e+04
# max    1000.00000  482130.000000  53394.000000  2.300000e+06

# %%
i = fortune['Employees'].idxmax()
fortune.loc[i]
# Out:
# Rank                             1
# Company                    Walmart
# Sector                   Retailing
# Industry     General Merchandisers
# Location           Bentonville, AR
# Revenue                     482130
# Profits                      14694
# Employees                  2300000
# Name: 0, dtype: object

# %%
j = fortune['Employees'].idxmin()
fortune.loc[j]
# Out:
# Rank                            426
# Company      A-Mark Precious Metals
# Sector                    Materials
# Industry              Miscellaneous
# Location           Santa Monica, CA
# Revenue                        6070
# Profits                           7
# Employees                        52
# Name: 425, dtype: object

# %%
fortune['Profits'][i]
fortune['Profits'][j]
# Out:
# np.int64(7)

# %%
fortune.duplicated().sum()
# Out:
# np.int64(4)

# %%
fortune.drop_duplicates(inplace=True)

# %%
sektori = fortune.groupby('Sector')

# %%
type(fortune)
# Out:
# pandas.core.frame.DataFrame

# %%
len(sektori)
# Out:
# 21

# %%
fortune['Sector'].nunique()
# Out:
# 21

# %%
sektori.size()
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          120
# Engineering & Construction       26
# Financials                      137
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %%
sektori.value_counts()
# Out:
# Sector               Rank  Company                          Industry                  Location          Revenue  Profits  Employees
# Aerospace & Defense  24    Boeing                           Aerospace and Defense     Chicago, IL       96114     5176    161400       1
#                      45    United Technologies              Aerospace and Defense     Farmington, CT    61047     7608    197200       1
#                      60    Lockheed Martin                  Aerospace and Defense     Bethesda, MD      46132     3605    126000       1
#                      88    General Dynamics                 Aerospace and Defense     Falls Church, VA  31469     2965    99900        1
#                      118   Northrop Grumman                 Aerospace and Defense     Falls Church, VA  23526     1990    65000        1
#                                                                                                                                       ..
# ...

# %%
fortune['Sector'].value_counts()
# Out:
# Sector
# Financials                      137
# Energy                          120
# Technology                      102
# Retailing                        80
# Health Care                      75
# Business Services                51
# Industrials                      46
# Materials                        43
# Food, Beverages & Tobacco        43
# Wholesalers                      40
# Transportation                   36
# Chemicals                        30
# Household Products               28
# Engineering & Construction       26
# Media                            25
# Hotels, Resturants & Leisure     25
# Motor Vehicles & Parts           24
# Aerospace & Defense              20
# Telecommunications               15
# Food and Drug Stores             15
# Apparel                          15
# Name: count, dtype: int64

# %%
sektori.first()
# Out:
#                               Rank                 Company  \
# Sector
# Aerospace & Defense             24                  Boeing
# Apparel                         91                    Nike
# Business Services              144           ManpowerGroup
# Chemicals                       56            Dow Chemical
# Energy                           2             Exxon Mobil
# Engineering & Construction     155                   Fluor
# Financials                       4      Berkshire Hathaway
# Food and Drug Stores             7              CVS Health
# Food, Beverages & Tobacco       41  Archer Daniels Midland
# Health Care                      5                McKesson
# Hotels, Resturants & Leisure   109              McDonald’s
# Household Products              34        Procter & Gamble
# Industrials                     11        General Electric
# Materials                      126                   Alcoa
# Media                           53                  Disney
# ...

# %%
sektori.last()
# Out:
#                               Rank                            Company  \
# Sector
# Aerospace & Defense            987              Delta Tucker Holdings
# Apparel                        917                              Guess
# Business Services              993              DeVry Education Group
# Chemicals                      949                        H.B. Fuller
# Energy                         997          Portland General Electric
# Engineering & Construction     994                       MDC Holdings
# Financials                     996         New York Community Bancorp
# Food and Drug Stores           928                             Fred’s
# Food, Beverages & Tobacco      954         Alliance One International
# Health Care                    978                 Providence Service
# Hotels, Resturants & Leisure   999                            Wendy’s
# Household Products             992                             Revlon
# ...

# %%
sektori.get_group('Technology')
# Out:
#      Rank                Company      Sector  \
# 2       3                  Apple  Technology
# 17     18             Amazon.com  Technology
# 19     20                     HP  Technology
# 24     25              Microsoft  Technology
# 30     31                    IBM  Technology
# ..    ...                    ...         ...
# 969   970      Rackspace Hosting  Technology
# 970   971       VeriFone Systems  Technology
# 974   975   Super Micro Computer  Technology
# 983   984  Nuance Communications  Technology
# 989   990            F5 Networks  Technology
#
#                                        Industry         Location  Revenue  \
# 2                   Computers, Office Equipment    Cupertino, CA   233715
# 17              Internet Services and Retailing      Seattle, WA   107006
# 19                  Computers, Office Equipment    Palo Alto, CA   103355
# 24                            Computer Software      Redmond, WA    93580
# ...

# %%
fortune[fortune['Sector'] == 'Energy']
# Out:
#      Rank                    Company  Sector                      Industry  \
# 1       2                Exxon Mobil  Energy            Petroleum Refining
# 13     14                    Chevron  Energy            Petroleum Refining
# 29     30                Phillips 66  Energy            Petroleum Refining
# 31     32              Valero Energy  Energy            Petroleum Refining
# 41     42         Marathon Petroleum  Energy            Petroleum Refining
# ..    ...                        ...     ...                           ...
# 979   980                      Spire  Energy   Utilities: Gas and Electric
# 980   981                 WPX Energy  Energy  Mining, Crude-Oil Production
# 982   983   Adams Resources & Energy  Energy            Petroleum Refining
# 994   995                  EP Energy  Energy  Mining, Crude-Oil Production
# 996   997  Portland General Electric  Energy   Utilities: Gas and Electric
#
#             Location  Revenue  Profits  Employees
# ...

# %%
sektori.max()
# Out:
#                               Rank                 Company  \
# Sector
# Aerospace & Defense            987                Woodward
# Apparel                        917    Wolverine World Wide
# Business Services              993           Western Union
# Chemicals                      949       Westlake Chemical
# Energy                         997             Xcel Energy
# Engineering & Construction     994            Tutor Perini
# Financials                     996          Zions Bancorp.
# Food and Drug Stores           928      Whole Foods Market
# Food, Beverages & Tobacco      954         WhiteWave Foods
# Health Care                    978         inVentiv Health
# Hotels, Resturants & Leisure   999              Yum Brands
# Household Products             992           Vista Outdoor
# Industrials                   1000      Zebra Technologies
# Materials                      986  Worthington Industries
# Media                          989             iHeartMedia
# ...

# %%
sektori.min()
# Out:
#                               Rank                        Company  \
# Sector
# Aerospace & Defense             24                  B/E Aerospace
# Apparel                         91                       Carter’s
# Business Services              144                 ABM Industries
# Chemicals                       56                    A. Schulman
# Energy                           2                            AES
# Engineering & Construction     155                          AECOM
# Financials                       4                            AIG
# Food and Drug Stores             7                     CVS Health
# Food, Beverages & Tobacco       41     Alliance One International
# Health Care                      5                         AbbVie
# Hotels, Resturants & Leisure   109                Bloomin’ Brands
# Household Products              34                  Avon Products
# Industrials                     11                             3M
# ...

# %%
sektori['Profits'].sum()
# Out:
# Sector
# Aerospace & Defense              28742
# Apparel                           8236
# Business Services                28227
# Chemicals                        22628
# Energy                          -71178
# Engineering & Construction        5304
# Financials                      258589
# Food and Drug Stores             16759
# Food, Beverages & Tobacco        51417
# Health Care                     106114
# Hotels, Resturants & Leisure     20697
# Household Products               14428
# Industrials                      20764
# Materials                         4428
# Media                            24347
# Motor Vehicles & Parts           25898
# Retailing                        47830
# Technology                      180473
# Telecommunications               48637
# Transportation                   44169
# Wholesalers                       8233
# Name: Profits, dtype: int64

# %%
sektori.agg({'Revenue': 'sum', 'Profits': 'sum', 'Employees': 'mean'})
# Out:
#                               Revenue  Profits     Employees
# Sector
# Aerospace & Defense            357940    28742  48402.850000
# Apparel                         95968     8236  23093.133333
# Business Services              272195    28227  26687.254902
# Chemicals                      243897    22628  15455.033333
# Energy                        1512778   -71178   9865.716667
# Engineering & Construction     153983     5304  15642.615385
# Financials                    2206098   258589  24348.846715
# Food and Drug Stores           483769    16759  93026.533333
# Food, Beverages & Tobacco      555967    51417  28177.488372
# Health Care                   1614707   106114  35710.520000
# Hotels, Resturants & Leisure   169546    20697  99369.800000
# Household Products             234737    14428  23072.785714
# Industrials                    497581    20764  33591.934783
# Materials                      259145     4428  14840.069767
# ...

# %%
auta = pd.read_csv('auta.csv')

# %%
auta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28553 entries, 0 to 28552
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     28553 non-null  int64
#  1   id             28553 non-null  int64
#  2   Kubikaža       28540 non-null  float64
#  3   Broj vrata     28549 non-null  object
#  4   Gorivo         28553 non-null  object
#  5   Kilovata (KW)  28543 non-null  float64
#  6   Lokacija       28553 non-null  object
#  7   Proizvođač     28553 non-null  object
#  8   Kilometraža    28551 non-null  float64
#  9   Model          28553 non-null  object
#  10  Cijena         26870 non-null  float64
#  11  Naslov         28553 non-null  object
#  12  Godište        28551 non-null  float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 2.8+ MB

# %%
auta.head()
# Out:
#    Unnamed: 0        id  Kubikaža Broj vrata  Gorivo  Kilovata (KW)  \
# 0           0  53790160       1.9        4/5   Dizel           88.0
# 1           1  52440211       2.0        4/5  Benzin          206.0
# 2           2  49131197       1.5        4/5  Hibrid           96.0
# 3           3  53468631       1.9        4/5   Dizel           85.0
# 4           4  53608637       1.9        2/3   Dizel           85.0
#
#      Lokacija  Proizvođač  Kilometraža     Model    Cijena  \
# 0  Banja Luka  Alfa Romeo     299500.0  Alfa 147    7500.0
# 1     Laktaši  Alfa Romeo          1.0   Stelvio  131500.0
# 2     Laktaši  Alfa Romeo          5.0    Tonale   85990.0
# 3     Vogošća  Alfa Romeo     300000.0  Alfa 156    1999.0
# 4      Visoko  Alfa Romeo     289121.0  Alfa 147    3900.0
#
#                                               Naslov  Godište
# 0                                Alfa Romeo Alfa 147   2005.0
# 1      NARUDŽBA ALFA ROMEO STELVIO 2.0TB 280KS AT Q4   2023.0
# ...

# %%
auta.isna().sum()
# Out:
# Unnamed: 0          0
# id                  0
# Kubikaža           13
# Broj vrata          4
# Gorivo              0
# Kilovata (KW)      10
# Lokacija            0
# Proizvođač          0
# Kilometraža         2
# Model               0
# Cijena           1683
# Naslov              0
# Godište             2
# dtype: int64

# %%
ukupno = auta.shape[0] * auta.shape[1]
broj_n = auta.isnull().sum().sum()
iznos = broj_n/ukupno*100
iznos
# Out:
# np.float64(0.46175937325728944)

# %%
auta.duplicated().sum()
# Out:
# np.int64(0)

# %%
auta.drop(['Naslov', 'id'], axis=1, inplace=True)

# %%
auta.head()
# Out:
#    Unnamed: 0  Kubikaža Broj vrata  Gorivo  Kilovata (KW)    Lokacija  \
# 0           0       1.9        4/5   Dizel           88.0  Banja Luka
# 1           1       2.0        4/5  Benzin          206.0     Laktaši
# 2           2       1.5        4/5  Hibrid           96.0     Laktaši
# 3           3       1.9        4/5   Dizel           85.0     Vogošća
# 4           4       1.9        2/3   Dizel           85.0      Visoko
#
#    Proizvođač  Kilometraža     Model    Cijena  Godište
# 0  Alfa Romeo     299500.0  Alfa 147    7500.0   2005.0
# 1  Alfa Romeo          1.0   Stelvio  131500.0   2023.0
# 2  Alfa Romeo          5.0    Tonale   85990.0   2022.0
# 3  Alfa Romeo     300000.0  Alfa 156    1999.0   2001.0
# 4  Alfa Romeo     289121.0  Alfa 147    3900.0   2003.0

# %%
auta.drop('Unnamed:0', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 auta.drop('Unnamed:0', axis=1, inplace=True)
#
# File c:\Users\Python\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
auta['Cijena'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 28553 entries, 0 to 28552
# Series name: Cijena
# Non-Null Count  Dtype
# --------------  -----
# 26870 non-null  float64
# dtypes: float64(1)
# memory usage: 223.2 KB

# %%
auta['Cijena'].describe()
# Out:
# count     26870.000000
# mean      22379.466022
# std       25586.358715
# min           2.000000
# 25%        8500.000000
# 50%       14990.000000
# 75%       26900.000000
# max      757000.000000
# Name: Cijena, dtype: float64

# %%
i = auta['Cijena'].idxmin()
auta.loc[i]
# Out:
# Unnamed: 0                          27911
# Kubikaža                              1.9
# Broj vrata                            4/5
# Gorivo                              Dizel
# Kilovata (KW)                        85.0
# Lokacija         Sarajevo - Novo Sarajevo
# Proizvođač                           Fiat
# Kilometraža                         265.0
# Model                               Stilo
# Cijena                                2.0
# Godište                            2003.0
# Name: 27911, dtype: object

# %%
auta.drop([i], axis=0, inplace=True)

# %%
i = auta['Cijena'].idxmin()
auta.loc[i]
# Out:
# Unnamed: 0            4340
# Kubikaža               1.2
# Broj vrata             4/5
# Gorivo                Plin
# Kilovata (KW)         50.0
# Lokacija            Mostar
# Proizvođač       Chevrolet
# Kilometraža       120000.0
# Model                 Aveo
# Cijena                35.0
# Godište             2010.0
# Name: 4340, dtype: object

# %%
auta.drop(auta[auta['Cijena'] < 500].index, inplace=True)

# %%
auta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28548 entries, 0 to 28552
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     28548 non-null  int64
#  1   Kubikaža       28535 non-null  float64
#  2   Broj vrata     28544 non-null  object
#  3   Gorivo         28548 non-null  object
#  4   Kilovata (KW)  28538 non-null  float64
#  5   Lokacija       28548 non-null  object
#  6   Proizvođač     28548 non-null  object
#  7   Kilometraža    28546 non-null  float64
#  8   Model          28548 non-null  object
#  9   Cijena         26865 non-null  float64
#  10  Godište        28546 non-null  float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 2.6+ MB

# %%
i = auta['Cijena'].idxmin()
auta.loc[i]
# Out:
# Unnamed: 0           6388
# Kubikaža              1.8
# Broj vrata            4/5
# Gorivo              Dizel
# Kilovata (KW)        55.0
# Lokacija          Zvornik
# Proizvođač           Ford
# Kilometraža      300000.0
# Model               Focus
# Cijena              500.0
# Godište            2001.0
# Name: 6388, dtype: object

# %%
auta['Kubikaža'].describe()
# Out:
# count    28535.000000
# mean         1.955269
# std          0.590085
# min          0.000000
# 25%          1.600000
# 50%          2.000000
# 75%          2.000000
# max          7.500000
# Name: Kubikaža, dtype: float64

# %%
auta['Proizvođač'].describe()
# Out:
# count          28548
# unique            67
# top       Volkswagen
# freq            6959
# Name: Proizvođač, dtype: object

# %%
i = auta['Kubikaža'].idxmin()
auta.loc[i]
# Out:
# Unnamed: 0                       5348
# Kubikaža                          0.0
# Broj vrata                        4/5
# Gorivo                        Elektro
# Kilovata (KW)                   101.0
# Lokacija         Sarajevo - Novi Grad
# Proizvođač                    Citroen
# Kilometraža                       0.0
# Model                              C4
# Cijena                            NaN
# Godište                        2022.0
# Name: 5348, dtype: object

# %%
auta.corr(['Cijena', 'Godište'], numeric_only=False)

# %%
auta[['Cijena', 'Godište']].corr()
# Out:
#            Cijena   Godište
# Cijena   1.000000  0.220714
# Godište  0.220714  1.000000

# %%
grupirano = auta.groupby('Proizvođač')['Cijena'].mean().idxmax()
grupirano
# Out:
# 'Lamborghini'

# %%
grupirano = auta.groupby('Proizvođač')['Godište'].mean().idxmin()
grupirano
# Out:
# 'Pontiac'

# %%
grupirano = auta.groupby('Proizvođač')['Godište'].mean().idxmax()
grupirano
# Out:
# 'Maybach'

# %%
auta['Kilometraža'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 28548 entries, 0 to 28552
# Series name: Kilometraža
# Non-Null Count  Dtype
# --------------  -----
# 28546 non-null  float64
# dtypes: float64(1)
# memory usage: 1.4 MB

# %%
auta['Kilometraža'].idxmax()
# Out:
# np.int64(185)

# %%
auta['Kilometraža'].idxmin()
# Out:
# np.int64(209)

# %%
i = auta['Kilometraža'].idxmax()
auta.loc[i]
# Out:
# Unnamed: 0                     185
# Kubikaža                       NaN
# Broj vrata                     2/3
# Gorivo                       Dizel
# Kilovata (KW)                  NaN
# Lokacija         Sarajevo - Centar
# Proizvođač              Alfa Romeo
# Kilometraža               999999.0
# Model                           GT
# Cijena                      8300.0
# Godište                     2006.0
# Name: 185, dtype: object

# %%
auta['Lokacija'].str.contains('Sarajevo', case=True, na=False).sum()
# Out:
# np.int64(3701)
