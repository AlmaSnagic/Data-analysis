# %%
import pandas as pd

# %%
df = pd.read_csv("bmw_pricing_challenge.csv")

# %%
df.head()
# Out:
#   maker_key model_key  mileage  engine_power registration_date    fuel  \
# 0       BMW       118   140411           100        2012-02-01  diesel
# 1       BMW        M4    13929           317        2016-04-01  petrol
# 2       BMW       320   183297           120        2012-04-01  diesel
# 3       BMW       420   128035           135        2014-07-01  diesel
# 4       BMW       425    97097           160        2014-12-01  diesel
#
#   paint_color     car_type  feature_1  feature_2  feature_3  feature_4  \
# 0       black  convertible       True       True      False      False
# 1        grey  convertible       True       True      False      False
# 2       white  convertible      False      False      False      False
# 3         red  convertible       True       True      False      False
# 4      silver  convertible       True       True      False      False
#
#    feature_5  feature_6  feature_7  feature_8  price     sold_at
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4843 entries, 0 to 4842
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   maker_key          4843 non-null   object
#  1   model_key          4843 non-null   object
#  2   mileage            4843 non-null   int64
#  3   engine_power       4843 non-null   int64
#  4   registration_date  4843 non-null   object
#  5   fuel               4843 non-null   object
#  6   paint_color        4843 non-null   object
#  7   car_type           4843 non-null   object
#  8   feature_1          4843 non-null   bool
#  9   feature_2          4843 non-null   bool
#  10  feature_3          4843 non-null   bool
#  11  feature_4          4843 non-null   bool
#  12  feature_5          4843 non-null   bool
#  13  feature_6          4843 non-null   bool
#  14  feature_7          4843 non-null   bool
#  15  feature_8          4843 non-null   bool
# ...

# %%
df["model_key"].unique()
# Out:
# array(['118', 'M4', '320', '420', '425', '335', '325', 'Z4', '120', '220',
#        '650', '135', '218', '318', '430', 'M3', '330', '225', 'M235',
#        '316', '435', '640', '640 Gran Coupé', '435 Gran Coupé', 'i8',
#        '630', '430 Gran Coupé', '635', '520', '525', '530', '535',
#        '320 Gran Turismo', '518', '116', '328', '523', 'X3', 'M550',
#        '528', '325 Gran Turismo', '125', '318 Gran Turismo',
#        '420 Gran Coupé', 'i3', '114', '520 Gran Turismo',
#        '530 Gran Turismo', 'M135', '418 Gran Coupé', '330 Gran Turismo',
#        '335 Gran Turismo', '730', '123', '535 Gran Turismo', '740', '750',
#        'ActiveHybrid 5', '735', 'M5', 'X5', 'X1', 'X4', 'X6', 'X6 M',
#        'X5 M', 'X5 M50', '218 Active Tourer', '218 Gran Tourer', '216',
#        '220 Active Tourer', '216 Gran Tourer', '216 Active Tourer',
#        '225 Active Tourer', '214 Gran Tourer'], dtype=object)

# %%
len(df["model_key"].unique())
# Out:
# 75

# %%
len(df["model_key"])
# Out:
# 4843

# %%
df[df["mileage"] < 50000]
# Out:
#      maker_key          model_key  mileage  engine_power registration_date  \
# 1          BMW                 M4    13929           317        2016-04-01
# 16         BMW                220    21167           135        2015-07-01
# 17         BMW                650    24521           270        2008-01-01
# 21         BMW                218    24868           100        2016-01-01
# 23         BMW                220    46963           140        2015-10-01
# ...        ...                ...      ...           ...               ...
# 4834       BMW    218 Gran Tourer    47782           110        2015-10-01
# 4838       BMW    218 Gran Tourer    39743           110        2015-10-01
# 4839       BMW  218 Active Tourer    49832           100        2015-06-01
# 4840       BMW    218 Gran Tourer    19633           110        2015-10-01
# 4841       BMW  218 Active Tourer    27920           110        2016-04-01
#
# ...

# %%
def konverzija (x):
    return x*1.619

df["mileage"] = df["mileage"].apply(konverzija)

df[df["mileage"] < 50000]
# Out:
#      maker_key          model_key    mileage  engine_power registration_date  \
# 1          BMW                 M4  22551.051           317        2016-04-01
# 16         BMW                220  34269.373           135        2015-07-01
# 17         BMW                650  39699.499           270        2008-01-01
# 21         BMW                218  40261.292           100        2016-01-01
# 32         BMW                218  40555.950           100        2016-01-01
# ...        ...                ...        ...           ...               ...
# 4826       BMW    214 Gran Tourer  46259.687            70        2015-08-01
# 4832       BMW    218 Gran Tourer  40445.858           100        2015-10-01
# 4833       BMW  216 Active Tourer  23528.927            85        2015-04-01
# 4840       BMW    218 Gran Tourer  31785.827           110        2015-10-01
# 4841       BMW  218 Active Tourer  45202.480           110        2016-04-01
#
# ...

# %%
def godina (x):
    return x[:4]

df["godina_proizvodnje"] = df["registration_date"].apply(godina)

df["godina_proizvodnje"]
# Out:
# 0       2012
# 1       2016
# 2       2012
# 3       2014
# 4       2014
#         ...
# 4838    2015
# 4839    2015
# 4840    2015
# 4841    2016
# 4842    2013
# Name: godina_proizvodnje, Length: 4843, dtype: object

# %%
(df["godina_proizvodnje"] < '2018')
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 4838    True
# 4839    True
# 4840    True
# 4841    True
# 4842    True
# Name: godina_proizvodnje, Length: 4843, dtype: bool

# %%
df[(df["godina_proizvodnje"] > '2015') & (df["godina_proizvodnje"] < '2018')]
# Out:
#      maker_key          model_key    mileage  engine_power registration_date  \
# 1          BMW                 M4  22551.051           317        2016-04-01
# 21         BMW                218  40261.292           100        2016-01-01
# 32         BMW                218  40555.950           100        2016-01-01
# 38         BMW                218  27955.273           110        2016-03-01
# 45         BMW                218  21259.089           110        2016-04-01
# ...        ...                ...        ...           ...               ...
# 4763       BMW                 X3  21714.028           100        2016-06-01
# 4808       BMW    216 Gran Tourer  76726.029            85        2016-02-01
# 4809       BMW    218 Gran Tourer  50057.861            85        2016-05-01
# 4830       BMW    216 Gran Tourer  77731.428            85        2016-02-01
# 4841       BMW  218 Active Tourer  45202.480           110        2016-04-01
#
# ...

# %%
df.drop(['feature_1', 'feature_2'], axis=1)
# Out:
#      maker_key          model_key     mileage  engine_power registration_date  \
# 0          BMW                118  227325.409           100        2012-02-01
# 1          BMW                 M4   22551.051           317        2016-04-01
# 2          BMW                320  296757.843           120        2012-04-01
# 3          BMW                420  207288.665           135        2014-07-01
# 4          BMW                425  157200.043           160        2014-12-01
# ...        ...                ...         ...           ...               ...
# 4838       BMW    218 Gran Tourer   64343.917           110        2015-10-01
# 4839       BMW  218 Active Tourer   80678.008           100        2015-06-01
# 4840       BMW    218 Gran Tourer   31785.827           110        2015-10-01
# 4841       BMW  218 Active Tourer   45202.480           110        2016-04-01
# 4842       BMW                525  317064.960           160        2013-01-01
#
# ...

# %%
df.drop(['feature_1', 'feature_2','feature_3', 'feature_4','feature_5', 'feature_6','feature_7', 'feature_8'], axis=1)
# Out:
#      maker_key          model_key     mileage  engine_power registration_date  \
# 0          BMW                118  227325.409           100        2012-02-01
# 1          BMW                 M4   22551.051           317        2016-04-01
# 2          BMW                320  296757.843           120        2012-04-01
# 3          BMW                420  207288.665           135        2014-07-01
# 4          BMW                425  157200.043           160        2014-12-01
# ...        ...                ...         ...           ...               ...
# 4838       BMW    218 Gran Tourer   64343.917           110        2015-10-01
# 4839       BMW  218 Active Tourer   80678.008           100        2015-06-01
# 4840       BMW    218 Gran Tourer   31785.827           110        2015-10-01
# 4841       BMW  218 Active Tourer   45202.480           110        2016-04-01
# 4842       BMW                525  317064.960           160        2013-01-01
#
# ...

# %%
df[(df["fuel"] == 'petrol') & (df["engine_power"] > 200)]
# Out:
#      maker_key         model_key     mileage  engine_power registration_date  \
# 1          BMW                M4   22551.051           317        2016-04-01
# 5          BMW               335  246657.888           225        2011-05-01
# 17         BMW               650   39699.499           270        2008-01-01
# 20         BMW               135  204338.847           225        2013-02-01
# 37         BMW               650   39587.788           270        2008-01-01
# 41         BMW                M3  438598.433           236        1996-08-01
# 57         BMW              M235   55178.758           240        2015-11-01
# 60         BMW               435   42194.378           225        2015-02-01
# 62         BMW               435   73722.784           250        2014-10-01
# 67         BMW                M3   48448.575           309        2012-09-01
# 72         BMW                M4  112374.790           317        2015-02-01
# ...

# %%
df["price"].mean()
# Out:
# np.float64(15828.081767499483)

# %%
df.loc[df["price"].idxmax()]
# Out:
# maker_key                    BMW
# model_key                     X3
# mileage               117401.785
# engine_power                 135
# registration_date     2013-03-01
# fuel                      diesel
# paint_color                 blue
# car_type                     suv
# feature_1                  False
# feature_2                  False
# feature_3                   True
# feature_4                  False
# feature_5                  False
# feature_6                  False
# feature_7                  False
# feature_8                   True
# price                     178500
# sold_at               2018-08-01
# godina_proizvodnje          2013
# Name: 4753, dtype: object

# %%
df.loc[df["price"].idxmin()]
# Out:
# maker_key                    BMW
# model_key                    320
# mileage               290380.602
# engine_power                 120
# registration_date     2013-06-01
# fuel                      diesel
# paint_color                black
# car_type                  estate
# feature_1                  False
# feature_2                   True
# feature_3                  False
# feature_4                  False
# feature_5                  False
# feature_6                  False
# feature_7                   True
# feature_8                   True
# price                        100
# sold_at               2018-03-01
# godina_proizvodnje          2013
# Name: 565, dtype: object

# %%
df["price"].sort_values()
# Out:
# 630        100
# 2829       100
# 879        100
# 1832       100
# 565        100
#          ...
# 2938     75000
# 4146     82400
# 90       95200
# 4684    142800
# 4753    178500
# Name: price, Length: 4843, dtype: int64
